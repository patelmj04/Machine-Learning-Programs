# %% [markdown]
# ## Mit Patel
# ### A3_44

# %%
print("Hello World")
# Out:
# Hello World

# %%
import pandas as pd
df = pd.read_csv("pract2.csv")

# %%
import numpy as np

x = np.array([5.0, 5.1, 5.2, 5.3, 5.4, 5.5, 5.6, 5.7, 5.8])
y = np.array([53, 55, 59, 61, 65, 68, 70, 74, 76])

# %%
x_mean = np.mean(x)
y_mean = np.mean(y)

# %%
numerator = np.sum((x - x_mean) * (y - y_mean))
denominator = np.sum((x - x_mean) ** 2)
w1 = numerator / denominator
w0 = y_mean - w1 * x_mean

# %%
print(f"Regression Coefficients: w0 = {w0}, w1 = {w1}")
# Out:
# Regression Coefficients: w0 = -95.64444444444449, w1 = 29.666666666666675

# %%
def predict(x):
    return w0 + w1 * x

height = 5.75
predicted_weight = predict(height)

pred = predict(x)
mae = np.mean(np.abs(y - pred))
mse = np.mean((y - pred) ** 2)

print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
# Out:
# Mean Absolute Error (MAE): 0.479012345679013
# Mean Squared Error (MSE): 0.2395061728395062

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x, y, color='blue', label='Data points')
plt.plot(x, pred, color='red', label='Regression line')
plt.xlabel('Height (feet)')
plt.ylabel('Weight (kg)')
plt.legend()
plt.show()
